# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import r2_score
import plotly.express as px

# Load the merged dataset
df = pd.read_csv("merged_college_data.csv")

# Show basic info
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   School Name               124 non-null    object
#  1   State                     124 non-null    object
#  2   In-State Tuition          124 non-null    float64
#  3   Out-of-State Tuition      124 non-null    float64
#  4   Median Earnings (10 yrs)  124 non-null    float64
#  5   Acceptance Rate           76 non-null     float64
#  6   Student Population        124 non-null    float64
#  7   Graduation Rate           122 non-null    float64
#  8   SAT Score                 45 non-null     float64
#  9   ACT Score                 45 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 9.8+ KB
#                   School Name State  In-State Tuition  Out-of-State Tuition  \
# 0  Glendale Community College    AZ            2358.0                8959.0
# 1  Glendale Community College    CA            2358.0                8959.0
# 2   GateWay Community College    AZ            2358.0                8959.0
# 3                Dine College    AZ            1410.0                1410.0
# 4          Rio Salado College    AZ            2358.0                8958.0
#
#    Median Earnings (10 yrs)  Acceptance Rate  Student Population  \
# 0                   43108.0              NaN             13480.0
# 1                   41540.0              NaN             13480.0
# 2                   46147.0              NaN              5123.0
# 3                   29188.0              NaN              1836.0
# 4                   41015.0              NaN             18631.0
#
#    Graduation Rate  SAT Score  ACT Score
# 0             14.0        NaN        NaN
# 1             14.0        NaN        NaN
# 2             20.0        NaN        NaN
# 3              5.0        NaN        NaN
# 4              4.0        NaN        NaN

# %%
# Descriptive statistics for Median Earnings
df["Median Earnings (10 yrs)"].describe()
# Out:
# count       124.000000
# mean      52308.782258
# std       14899.213909
# min       29188.000000
# 25%       41430.500000
# 50%       45880.500000
# 75%       61374.750000
# max      102772.000000
# Name: Median Earnings (10 yrs), dtype: float64

# %% [markdown]
# # Q1: Does Higher Tuition Correlate with Graduate Salaries?

# %%
# Scatterplot of In-State Tuition vs Median Earnings
plt.figure(figsize=(8, 5))
sns.regplot(
    data=df,
    x="In-State Tuition",
    y="Median Earnings (10 yrs)",
    scatter_kws={'color': '#4C72B0', 's': 30, 'alpha': 0.7},
    line_kws={'color': '#4C72B0', 'linewidth': 2},
    ci=None
)
plt.title("In-State Tuition vs. Median Earnings", fontsize=16, weight='bold')
plt.xlabel("In-State Tuition ($)", fontsize=12)
plt.ylabel("Median Earnings (10 yrs)", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# Calculate correlation
correlation = df["In-State Tuition"].corr(df["Median Earnings (10 yrs)"])
print(f"Correlation between In-State Tuition and Median Earnings:{correlation: .4f}")
# Out:
# Correlation between In-State Tuition and Median Earnings: 0.7086

# %%
# Define groups
median_tuition = df["In-State Tuition"].median()
high_tuition = df[df["In-State Tuition"] > median_tuition]["Median Earnings (10 yrs)"]
low_tuition = df[df["In-State Tuition"] <= median_tuition]["Median Earnings (10 yrs)"]

# State hypotheses
print("Null Hypothesis: There is no difference in median earnings between high tuition and low tuition schools.")
print("Alternative Hypothesis: There is a difference in median earnings between high tuition and low tuition schools.")

# T-test
t_stat, p_value = stats.ttest_ind(high_tuition, low_tuition, equal_var=False)
print("T-test Statistic:", round(t_stat, 4))
print("P-Value:", round(p_value, 4))
# Out:
# Null Hypothesis: There is no difference in median earnings between high tuition and low tuition schools.
# Alternative Hypothesis: There is a difference in median earnings between high tuition and low tuition schools.
# T-test Statistic: 6.3711
# P-Value: 0.0

# %%
# Select tuition as input and earnings as output
X = df[["In-State Tuition"]]
y = df["Median Earnings (10 yrs)"]

# Create and train the model
model = LinearRegression()
model.fit(X, y)

# Predict earnings based on tuition
df["Predicted Earnings"] = model.predict(X)

# Plot regression
plt.figure(figsize=(8,6))
sns.scatterplot(x=df["In-State Tuition"], y=df["Median Earnings (10 yrs)"], label="Actual")
sns.lineplot(x=df["In-State Tuition"], y=df["Predicted Earnings"], color="red", label="Regression Line")
plt.title("Simple Linear Regression: Predicting Earnings from Tuition")
plt.xlabel("In-State Tuition ($)")
plt.ylabel("Median Earnings (10 Years)")
plt.legend()
plt.grid(True)
plt.show()

# Output model coefficients
print(f"Regression Slope (Coefficient): {model.coef_[0]:.4f}")
print(f"Regression Intercept: {model.intercept_:.4f}")

# R-squared
r2 = r2_score(y, df["Predicted Earnings"])
print(f"R² Score: {r2:.4f}")
# Out:
# Regression Slope (Coefficient): 2.2267
# Regression Intercept: 35026.6135
# R² Score: 0.5021

# %% [markdown]
# # Q2: Does Graduation Rate Predict Salary Outcomes?

# %%
# Scatterplot: Graduation Rate vs Median Earnings
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="Graduation Rate", y="Median Earnings (10 yrs)")
plt.title("Graduation Rate vs Median Earnings")
plt.xlabel("Graduation Rate (%)")
plt.ylabel("Median Earnings (10 Years)")
plt.grid(True)
plt.show()

# Correlation
grad_corr = df["Graduation Rate"].corr(df["Median Earnings (10 yrs)"])
print(f"Correlation between Graduation Rate and Median Earnings: {grad_corr:.4f}")
# Out:
# Correlation between Graduation Rate and Median Earnings: 0.8004

# %%
# Bar chart bins
bins = [0, 25, 50, 75, 100]
labels = ['0–25%', '26–50%', '51–75%', '76–100%']
df['Grad Rate Group'] = pd.cut(df['Graduation Rate'], bins=bins, labels=labels)

# Add observed=False to groupby
grouped = df.groupby('Grad Rate Group', observed=False)['Median Earnings (10 yrs)'].mean().reset_index()

# Sort categories
grouped['Grad Rate Group'] = pd.Categorical(grouped['Grad Rate Group'], categories=labels, ordered=True)
grouped = grouped.sort_values('Grad Rate Group')

# Create the bar chart
plt.figure(figsize=(8, 5))
sns.barplot(
    data=grouped,
    x='Grad Rate Group',
    y='Median Earnings (10 yrs)',
    color='#4C72B0'
)
plt.title('Earnings by Graduation Rate Group', fontsize=16, weight='bold')
plt.xlabel('Graduation Rate Group', fontsize=12)
plt.ylabel('Median Earnings (10 yrs)', fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q3:  Are There Regional Differences in Earnings?

# %%
# Count the number of schools per state
state_counts = df['State'].value_counts().reset_index()
state_counts.columns = ['State', 'Number of Schools']
state_counts.sort_values(by='Number of Schools', ascending=False, inplace=True)

# Preview
state_counts.head(10)
# Out:
#   State  Number of Schools
# 0    CA                 34
# 1    FL                 28
# 2    AL                 14
# 3    CO                 12
# 4    AR                 11
# 5    AZ                  8
# 6    GA                  5
# 7    CT                  4
# 8    AK                  3
# 9    DE                  2

# %%
# Filter out states with < 3 schools
valid_states = state_counts[state_counts["Number of Schools"] >= 3]["State"]
filtered_df = df[df["State"].isin(valid_states)]

# Calculate average earnings by state
state_earnings = filtered_df.groupby("State")["Median Earnings (10 yrs)"].mean().reset_index()

# Plot choropleth map
fig = px.choropleth(
    state_earnings,
    locations='State',
    locationmode='USA-states',
    color='Median Earnings (10 yrs)',
    color_continuous_scale='Blues',
    scope='usa',
    title='Average Graduate Earnings by State (3+ Colleges Only)',
    labels={'Median Earnings (10 yrs)': 'Median Earnings'}
)

fig.update_layout(
    geo=dict(bgcolor='rgba(0,0,0,0)'),
    margin={"r":0,"t":50,"l":0,"b":0},
    font=dict(size=12)
)

fig.show()
